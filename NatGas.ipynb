# %%
### Natural Gas

# %%
# Import all necessary libraries.
import pandas as pd 
import numpy as np 
import scipy as scp
import sklearn
from sklearn import metrics

# Provides classes and functions to estimate many different statistical methods.
import statsmodels.api as sm  

# Note: Helps split data into sets and balance the data.
from imblearn.over_sampling import SMOTE  
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV

# Note: Indicates situations that aren’t necessarily exceptions.
import warnings  
warnings.filterwarnings('ignore')  

# Read the provided CSV file/data set.
df = pd.read_csv('Nat_Gas.csv')  

# Print a summary of the DataFrame to sense-check it.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48 entries, 0 to 47
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Dates   48 non-null     object
#  1   Prices  48 non-null     float64
# dtypes: float64(1), object(1)
# memory usage: 900.0+ bytes

# %%
# Review the head of the data.
df.head()
# Out:
#       Dates  Prices
# 0  10/31/20    10.1
# 1  11/30/20    10.3
# 2  12/31/20    11.0
# 3   1/31/21    10.9
# 4   2/28/21    10.9

# %%
# Determine the number of null values.
df.isnull().sum()
# Out:
# Dates     0
# Prices    0
# dtype: int64

# %%
# Determine descriptive statistics.
df.describe()
# Out:
#           Prices
# count  48.000000
# mean   11.207083
# std     0.757897
# min     9.840000
# 25%    10.650000
# 50%    11.300000
# 75%    11.625000
# max    12.800000

# %%
# Inspect the dataset (assumes columns like 'Date' and 'Price')
print(df.head())
# Out:
#        Dates  Prices
# 0 2020-10-31    10.1
# 1 2020-11-30    10.3
# 2 2020-12-31    11.0
# 3 2021-01-31    10.9
# 4 2021-02-28    10.9

# %%
print(df.columns)
# Out:
# Index(['Dates', 'Prices'], dtype='object')

# %%
import pandas as pd
import matplotlib.pyplot as plt   # For plotting

plt.plot(df_filtered['Dates'], df_filtered['Prices'], marker='o', linestyle='-', label="Natural Gas Price")


# Convert the Dates column to datetime
df['Dates'] = pd.to_datetime(df['Dates'])

# Filter within the range
start_date = "2020-10-31"
end_date = "2024-09-30"
df_filtered = df[(df['Dates'] >= start_date) & (df['Dates'] <= end_date)]

# Ensure sorted by date
df_filtered = df_filtered.sort_values(by='Dates')

# Plotting
plt.figure(figsize=(12, 6))
plt.plot(df_filtered['Dates'], df_filtered['Prices'], marker='o', linestyle='-', label="Natural Gas Price")
plt.title("Monthly Purchase Price of Natural Gas (Oct 2020 – Sep 2024)")
plt.xlabel("Date")
plt.ylabel("Price")
plt.legend()
plt.grid(True)
plt.show()
